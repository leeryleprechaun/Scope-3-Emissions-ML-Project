# %% [markdown]
# <a href="https://colab.research.google.com/github/leeryleprechaun/MSDS_Practicum_Public/blob/main/Week_3_EDA_Public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Going to take a look at the smaller data set and play around with it a little
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Loading in THE ORIGINAL C6 data, I want to take a look at the "Relevant, Calculated" Columns againt
url=''
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df.head(2)

# %%
# Taking a look at the industries aggregated
group = df.groupby(['primary_sector'])['Account numberx'].count().reset_index()
group
# Out:
#                                        primary_sector  Account numberx
# 0                                       Air transport               10
# 1                          Bars, hotels & restaurants                7
# 2                                    Biotech & pharma               29
# 3                                   Cement & concrete                4
# 4                                           Chemicals               54
# 5                      Commercial & consumer services               10
# 6                                        Construction               29
# 7                                  Convenience retail                9
# 8                                Discretionary retail               21
# 9                   Electrical & electronic equipment               96
# 10                            Energy utility networks               14
# 11                           Entertainment facilities                3
# ...

# %% [markdown]
# # Status
# #### looked at the data in xcel to determine
# That gives us a list of about 933 companies that have revenue values
#
# That list drops to 810 when you remove companies that have no type of scope 3 verification
# Of those 810 companies 634 have values listed for purchased goods and services
# Of those 810 companies 325 have values listed for Use of sold products
# Of those 810 companies 305 have values listed for both Purchased goods and services AND Use of Sold Products

# %%
# Looking at my list of the smallest frame
url='https://drive.google.com/file/d/1Q1Sx6j_fU_MywleZdviX9CG0aZskEHLh/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
smalldf = pd.read_csv(url)
smalldf.head(2)

# %%
# Taking a look at the industries aggregated
group = smalldf.groupby(['primary_sector'])['revenue / emissions'].mean().reset_index()
group.sort_values(by='revenue / emissions')
group.sort_index()

# %%
# Taking a look at the industries aggregated
group = smalldf.groupby(['primary_activity'])['revenue / emissions'].mean().reset_index()
group.sort_values(by='revenue / emissions')
# Out:
#            primary_activity  revenue / emissions
# 9     Baked goods & cereals            40.649082
# 46          Iron ore mining            76.247902
# 57     Oil & gas extraction           112.341171
# 30         Engines & motors           161.478255
# 53  Nitrogenous fertilizers           219.570049
# ..                      ...                  ...
# 63          Other financial         48116.481510
# 26    Electronic components        133497.940477
# 68           Paper products        254131.698200
# 44                Insurance        325367.507130
# 10                    Banks        436161.318030
#
# [93 rows x 2 columns]

# %%
# Looking at my list of the smallest frame
url=''
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
smallerdf = pd.read_csv(url)
smallerdf.head(2)

group = smallerdf.groupby(['primary_sector'])['sold product vs rev'].mean().reset_index()
group.sort_values(by='sold product vs rev')
# Out:
#                                        primary_sector  sold product vs rev
# 25                  Oil & gas extraction & production         1.223333e+02
# 24                            Metallic mineral mining         2.090000e+02
# 26                               Oil & gas processing         3.586000e+02
# 23                 Metal smelting, refining & forming         3.885000e+02
# 27                                Oil & gas retailing         5.620000e+02
# 18                                Light manufacturing         5.860909e+02
# 9                             Energy utility networks         6.648182e+02
# 41                           Transportation equipment         1.122357e+03
# 33                                  Powered machinery         1.205496e+03
# 35                         Renewable power generation         3.866000e+03
# 1                          Bars, hotels & restaurants         3.940000e+03
# ...

# %%
group = smallerdf.groupby(['primary_sector'])['sold product vs rev.1'].mean().reset_index()
group.sort_values(by='sold product vs rev.1')
# Out:
#                                        primary_sector  sold product vs rev.1
# 25                  Oil & gas extraction & production           1.223333e+02
# 24                            Metallic mineral mining           2.090000e+02
# 26                               Oil & gas processing           3.586000e+02
# 23                 Metal smelting, refining & forming           3.885000e+02
# 27                                Oil & gas retailing           5.620000e+02
# 18                                Light manufacturing           5.860909e+02
# 9                             Energy utility networks           6.648182e+02
# 41                           Transportation equipment           1.122357e+03
# 33                                  Powered machinery           1.205496e+03
# 35                         Renewable power generation           3.866000e+03
# 1                          Bars, hotels & restaurants           3.940000e+03
# ...
